# %% [markdown]
# ### Task1

# %% [markdown]
# я запускал с другим портом ```torchrun --nproc_per_node=10 --master_port=29601 sequential_print.py``` тк там занят был

# %% [markdown]
# ### Task2

# %% [markdown]
# #### тесты на батчнорм

# %%
# !pytest test_syncbn.py -v --workers 1 --hid-dim 128 --batch-size 32
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 5.11s ===============================

# %%
# !pytest test_syncbn.py -v --workers 1 --hid-dim 128 --batch-size 64
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 5.11s ===============================

# %%
# !pytest test_syncbn.py -v --workers 1 --hid-dim 256 --batch-size 32
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 5.03s ===============================

# %%
# !pytest test_syncbn.py -v --workers 1 --hid-dim 256 --batch-size 64
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 5.11s ===============================

# %%
# !pytest test_syncbn.py -v --workers 1 --hid-dim 512 --batch-size 32
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 5.02s ===============================

# %%
# !pytest test_syncbn.py -v --workers 1 --hid-dim 512 --batch-size 64
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 5.07s ===============================

# %%
# !pytest test_syncbn.py -v --workers 1 --hid-dim 1024 --batch-size 32
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 5.10s ===============================

# %%
# !pytest test_syncbn.py -v --workers 1 --hid-dim 1024 --batch-size 64
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 5.04s ===============================

# %%
# !pytest test_syncbn.py -v --workers 4 --hid-dim 128 --batch-size 32
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 9.78s ===============================

# %%
# !pytest test_syncbn.py -v --workers 4 --hid-dim 128 --batch-size 64
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 10.28s ==============================

# %%
# !pytest test_syncbn.py -v --workers 4 --hid-dim 256 --batch-size 32
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 9.61s ===============================

# %%
# !pytest test_syncbn.py -v --workers 4 --hid-dim 256 --batch-size 64
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 9.83s ===============================

# %%
# !pytest test_syncbn.py -v --workers 4 --hid-dim 512 --batch-size 32
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 9.63s ===============================

# %%
# !pytest test_syncbn.py -v --workers 4 --hid-dim 512 --batch-size 64
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 9.65s ===============================

# %%
# !pytest test_syncbn.py -v --workers 4 --hid-dim 1024 --batch-size 32
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 10.57s ==============================

# %%
# !pytest test_syncbn.py -v --workers 4 --hid-dim 1024 --batch-size 64
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.10, pytest-8.3.4, pluggy-1.5.0 -- /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/nrchervov_1/efdl_hw/week03_data_parallel/homework
# collected 1 item
#
# test_syncbn.py::test_batchnorm PASSED                                    [100%]
#
# ============================== 1 passed in 9.98s ===============================

# %% [markdown]
# #### производительность пайплайна

# %%
# !CUDA_VISIBLE_DEVICES=0,1 torchrun --nproc_per_node 2 ddp_cifar100_pytorch.py
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# Files already downloaded and verified
# Files already downloaded and verified
# /home/nrchervov_1/efdl_hw/week03_data_parallel/homework/venv/lib/python3.8/site-packages/torch/distributed/distributed_c10d.py:2387: UserWarning: torch.distributed._all_gather_base is a private function and will be deprecated. Please use torch.distributed.all_gather_into_tensor instead.
#   warnings.warn(
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0,1 torchrun --nproc_per_node 2 ddp_cifar100.py
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# Files already downloaded and verified
# Files already downloaded and verified
# STAGE:2026-02-09 20:43:06 3906567:3906567 ActivityProfilerController.cpp:294] Completed Stage: Warm Up
# [W CPUAllocator.cpp:231] Memory block of unknown size was allocated before the profiling started, profiler results will not include the deallocation event
# STAGE:2026-02-09 20:43:06 3906568:3906568 ActivityProfilerController.cpp:294] Completed Stage: Warm Up
# [W CPUAllocator.cpp:231] Memory block of unknown size was allocated before the profiling started, profiler results will not include the deallocation event
# ...

# %% [markdown]
# видно что алгоритмы работают примерно одинаково, мой оказался на немного быстрее и по памяти лучше но я думаю это в рамках погрешности и мб у торча больше каких то случаев разобрано, также скор одинаковый до 4 знака минимум

# %% [markdown]
# профайл выглядит примерно одинаково - больше всего времени уходит на подготовку данных

# %% [markdown]
# ![alt text](image.png "Title")

# %% [markdown]
# #### my bn vs torch bn

# %%
# !CUDA_VISIBLE_DEVICES=0,1 torchrun --nproc_per_node 2 compare_bn.py
# Out:
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# my bn, for hidden 128 and batch size 32 Time: 0.12477874755859375, Max memory: 0.40625
# my bn, for hidden 128 and batch size 64 Time: 0.12556076049804688, Max memory: 0.1015625
# my bn, for hidden 256 and batch size 32 Time: 0.1268312931060791, Max memory: 0.10888671875
# my bn, for hidden 256 and batch size 64 Time: 0.12572503089904785, Max memory: 0.20263671875
# my bn, for hidden 512 and batch size 32 Time: 0.12646269798278809, Max memory: 0.21728515625
# my bn, for hidden 512 and batch size 64 Time: 0.1299750804901123, Max memory: 0.40478515625
# my bn, for hidden 1024 and batch size 32 Time: 0.12656092643737793, Max memory: 0.43408203125
# ...

# %% [markdown]
# тут можно видеть что алгосы работают схоже, у меня чуть быстрее получается, но чуть больше памяти ест
